# %%
import pandas as pd
import numpy as np
df = pd.read_csv("netflix_titles.csv")
print(df.shape)
df.head()
# Out:
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Task 1

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# Task 2

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Task 3

# %%
df.dropna(subset=['title', 'type'], inplace=True)

# %% [markdown]
# Task 4

# %%
df[df["type"]=="Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# Task 5

# %%
df['type_length'] = df['title'].apply(len)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Task 6

# %%
df['has_description'] =np.where(df['description'].isnull(),0,1)
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %% [markdown]
# Task 7

# %%
df['country'].value_counts().head(5)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Name: count, dtype: int64

# %% [markdown]
# Task 8

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] = df['date_added'].dt.year
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# Task 9

# %%
df['before_2010'] = np.where(df['year_added']<2010,1,0)
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  type_length  \
# 0  As her father nears the end of his life, filmm...           20
# 1  After crossing paths at a party, a Cape Town t...           13
#
#    has_description  year_added  before_2010
# ...

# %% [markdown]
# Task 10

# %%
df[(df['listed_in'].str.contains('Horror', na=False)) & 
   (df['country'] == 'India')]
# Out:
#      show_id     type                          title  \
# 200     s201    Movie                Krishna Cottage
# 210     s211    Movie                     Ragini MMS
# 211     s212    Movie                   Ragini MMS 2
# 1087   s1088    Movie                          Roohi
# 1653   s1654    Movie                    Andhakaaram
# 1777   s1778    Movie                    Kaali Khuhi
# 2342   s2343    Movie                        Bulbbul
# 2472   s2473  TV Show                         Betaal
# 2589   s2590    Movie                         Psycho
# 2729   s2730    Movie                           Kaal
# 3060   s3061    Movie                  Ghost Stories
# 3077   s3078    Movie                         Aaviri
# 3655   s3656  TV Show                     Typewriter
# 3729   s3730    Movie                       Rakkhosh
# 3768   s3769    Movie                          Stree
# 4395   s4396    Movie        Savita Damodar Paranjpe
# 4558   s4559    Movie                         Agyaat
# ...

# %% [markdown]
# Task 11

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %% [markdown]
# Task 12

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Task 13

# %%
df['rating'].fillna("Unkown",inplace= True)
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  type_length  \
# 0  As her father nears the end of his life, filmm...           20
# 1  After crossing paths at a party, a Cape Town t...           13
#
#    has_description  year_added  before_2010
# ...

# %% [markdown]
# Task 14

# %%
df['month_added'] = df['date_added'].dt.month
df['month_added'].value_counts().sort_index()
# Out:
# month_added
# 1.0     738
# 2.0     563
# 3.0     742
# 4.0     764
# 5.0     632
# 6.0     728
# 7.0     827
# 8.0     755
# 9.0     770
# 10.0    760
# 11.0    705
# 12.0    813
# Name: count, dtype: int64

# %% [markdown]
# Task 15

# %%
df['is_tv_show'] = np.where(df['type'] == "TV Show",1,0)
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %% [markdown]
# Task 16

# %%
df['short_description'] = df['description'].apply(lambda x: ' '.join(str(x).split()[:10]))
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  type_length  \
# 0  As her father nears the end of his life, filmm...           20
# 1  After crossing paths at a party, a Cape Town t...           13
#
#    has_description  year_added  before_2010  month_added  is_tv_show  \
# ...

# %% [markdown]
# Task 17

# %%
df[df['country'] == 'India'].shape[0]
# Out:
# 972

# %% [markdown]
# Task 18

# %%
df[df.duplicated('title', keep=False)].sort_values('title')
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, type_length, has_description, year_added, before_2010, month_added, is_tv_show, short_description]
# Index: []

# %% [markdown]
# Task 19

# %%
df['genre_count'] = df['listed_in'].apply(lambda x: len(str(x).split(',')))
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %% [markdown]
# Task 20

# %%
df[df['title'].str.startswith('A')]
# Out:
#      show_id     type                        title  \
# 22       s23    Movie              Avvai Shanmughi
# 30       s31    Movie              Ankahi Kahaniya
# 37       s38  TV Show                  Angry Birds
# 71       s72    Movie  A StoryBots Space Adventure
# 105     s106    Movie             Angamaly Diaries
# ...      ...      ...                          ...
# 6198   s6199  TV Show          Aussie Gold Hunters
# 6199   s6200    Movie                     Automata
# 6200   s6201    Movie       Avengers: Infinity War
# 6201   s6202    Movie         Avicii: True Stories
# 6202   s6203    Movie                        Azhar
#
#                                                director  \
# 22                                       K.S. Ravikumar
# 30    Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket C...
# 37                                                  NaN
# 71                                      David A. Vargas
# 105                                Lijo Jose Pellissery
# ...

# %% [markdown]
# Task 21

# %%
genre_split = df.assign(genre=df['listed_in'].str.split(','))
genre_exploded = genre_split.explode('genre')
genre_exploded['genre'] = genre_exploded['genre'].str.strip()
genre_exploded['genre'].value_counts().head(10)
# Out:
# genre
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %% [markdown]
# Task 22

# %%
df.groupby('country')['show_id'].count().sort_values(ascending=False).head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: show_id, dtype: int64

# %% [markdown]
# Task 23

# %%
df['desc_length'] = df['description'].apply(lambda x: len(str(x)))
df['desc_length'].max()
# Out:
# np.int64(248)

# %% [markdown]
# Task 24

# %%
df[df['release_year'] < 2000]
# Out:
#      show_id   type                                title          director  \
# 7         s8  Movie                              Sankofa      Haile Gerima
# 22       s23  Movie                      Avvai Shanmughi    K.S. Ravikumar
# 24       s25  Movie                                Jeans        S. Shankar
# 26       s27  Movie                       Minsara Kanavu       Rajiv Menon
# 41       s42  Movie                                 Jaws  Steven Spielberg
# ...      ...    ...                                  ...               ...
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory        Mel Stuart
# 8748   s8749  Movie                 Winter of Our Dreams       John Duigan
# 8763   s8764  Movie      WWII: Report from the Aleutians       John Huston
# 8764   s8765  Movie                           Wyatt Earp   Lawrence Kasdan
# 8792   s8793  Movie                          Young Tiger            Mu Chu
#
#                                                    cast  \
# ...

# %% [markdown]
# Task 25

# %%
df['country'].isnull().sum()
# Out:
# np.int64(831)
